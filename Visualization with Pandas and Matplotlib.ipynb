# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#ploting techniques on iris dataset
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#.plot using pandas 
ax=iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
from numpy.random import randn, randint,uniform, sample
ts=pd.Series(randn(1000), index=pd.date_range('2019-06-07', periods=1000))

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
ts.head()
# Out:
# 2019-06-07   -2.752621
# 2019-06-08    0.256722
# 2019-06-09   -0.138282
# 2019-06-10    1.605050
# 2019-06-11    2.459300
# Freq: D, dtype: float64

# %%
iris.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#hist 
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=iris.drop(['species'], axis=1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
#on random data
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0 -0.958267  0.629846 -0.489461  0.406493
# 1  0.897368  1.162074 -0.763292  0.406421
# 2 -0.487068  2.033057 -1.073844  1.699492
# 3 -1.599975 -0.357784  0.836084 -0.054556
# 4 -0.021624 -0.669828  1.618047  0.406277

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=False, bins=100) #stacked=Flase means overlapping will not be there
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', stacked=False, bins=50, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff() #difference between the values
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
df=iris.drop(['species'], axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color='b', alpha=0.1, figsize=(10,10)) #alpha=is for transperancy its value range from 0-1
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
#scatter plot 
df.plot.scatter(x='sepal_length', y='petal_length', c='r')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.scatter(df['sepal_length'], y=df['petal_length'], c=df['petal_length'])

# %%
df.plot.scatter(x='sepal_length', y='petal_length', label='Length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length', y='petal_length', c='sepal_width', s=190) #s is the pixcel value as the vaue increases balls increases
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#hexbin plot
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#pie plot
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d=df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True, figsize=(10,10))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots=True, figsize=(20,20), fontsize=26, autopct='%.2f')
#autopct is for what value we have to mention and .2f is upto 2 floating no the value should be
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(subplots=True, sharex=False, layout=(2,3), figsize=(16,8))
plt.tight_layout()
#layout is how many no of plots we want 
#sharex=sharing x axis to all the graphs

# %%
df.plot(subplots=True, sharex=True, layout=(2,3), figsize=(16,8))
plt.tight_layout()
